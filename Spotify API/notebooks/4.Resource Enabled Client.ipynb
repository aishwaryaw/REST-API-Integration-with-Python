# %%
import requests
import base64 
import datetime
from urllib.parse import urlencode
import pprint

# %%
client_id = 'client id'
client_secret = 'client secret'

# %%
class SpotifyAPI():
    client_id = None
    client_secret = None
    access_token = None
    access_token_expires_in = datetime.datetime.now()
    access_token_did_expire = False
    token_url = "https://accounts.spotify.com/api/token"

    def __init__(self, client_id , client_secret):
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client id and client secret")
        client_creds = f"{self.client_id}:{self.client_secret}"
        client_creds_base64 = base64.b64encode(client_creds.encode())
        return client_creds_base64
    
    def get_token_header(self):
        client_creds_base64 = self.get_client_credentials()
        token_header = {
        "Authorization": f"Basic {client_creds_base64.decode()}"  # <base64 encoded client_id:client_secret>
        }
        return token_header
          
    def get_token_data(self):
        return {
                "grant_type":"client_credentials"
                }

    def perform_auth(self):
        token_data = self.get_token_data()
        token_header = self.get_token_header()
        r = requests.post(self.token_url, data = token_data, headers =token_header)
        if r.status_code not in range(200,299):
#             print(r.status_code)
            return False
        
        data = r.json()
        access_token = data['access_token']
        expires_in = data['expires_in']
        now = datetime.datetime.now()
        expires = now + datetime.timedelta(seconds = expires_in) # to get the time of expiration 
        self.access_token = access_token
        self.access_token_expires_in = expires
        self.access_token_did_expire = expires < now # token expired = if time of expiration is less than current time 
        return True
         
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires_in
        now = datetime.datetime.now()
        if now > expires:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
               "Authorization" : f"Bearer {access_token}"     
        }
        return headers
    
    def get_resource(self ,lookup_id , resource_type="artist" , version="v1" ):
        headers = self.get_resource_header()
        lookup_url = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        r = requests.get(lookup_url , headers= headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id , resource_type="albums")
        
    def get_artist(self, _id):
        return self.get_resource(_id , resource_type="artists") 
        
    def search(self, query="Time", search_type="track"):
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({ "q": query, "type": search_type.lower() })
        lookup_url = f"{endpoint}{data}"
        r = requests.get(f"https://api.spotify.com/v1/search?{data}", headers = headers)
        pprint.pprint(r.json())

# %%
spotify = SpotifyAPI(client_id , client_secret)
# spotify.perform_auth()

# %%
# spotify.search(query="tania",search_type="Artist") 
spotify.get_artist("4rfeqiQmvXlc6LYxsgrXY7")
# spotify.get_album("1M4anG49aEs4YimBdj96Oy")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rfeqiQmvXlc6LYxsgrXY7'},
#  'followers': {'href': None, 'total': 9},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/artists/4rfeqiQmvXlc6LYxsgrXY7',
#  'id': '4rfeqiQmvXlc6LYxsgrXY7',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2734b17d92e59bf8b0953397803',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e024b17d92e59bf8b0953397803',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048514b17d92e59bf8b0953397803',
#    'width': 64}],
#  'name': 'Tania Barron',
#  'popularity': 39,
#  'type': 'artist',
#  'uri': 'spotify:artist:4rfeqiQmvXlc6LYxsgrXY7'}

# %%
# spotify.search(query="Arrival", type="album")
spotify.search("A lannister always pays his debts", search_type="track")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=A+lannister+always+pays+his+debts&type=track&offset=0&limit=20',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#                                               'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#                                               'id': '1hCkSJcXREhrodeIHQdav8',
#                                               'name': 'Ramin Djawadi',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/41zMFsCjcGenYKVJYUXU2n'},
#                                  'href': 'https://api.spotify.com/v1/albums/41zMFsCjcGenYKVJYUXU2n',
#                                  'id': '41zMFsCjcGenYKVJYUXU2n',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27362be9b16adb2e32aed9bda26',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0262be9b16adb2e32aed9bda26',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485162be9b16adb2e32aed9bda26',
#                                              'width': 64}],
#                                  'name': 'Game Of Thrones: Season 3 (Music '
#                                          'from the HBO Series)',
#                                  'release_date': '2013-06-04',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 19,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:41zMFsCjcGenYKVJYUXU2n'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#                                     'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#                                     'id': '1hCkSJcXREhrodeIHQdav8',
#                                     'name': 'Ramin Djawadi',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 170560,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USNLR1300355'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1vPEPhmGDnp8RR6GCBozaa'},
#                        'href': 'https://api.spotify.com/v1/tracks/1vPEPhmGDnp8RR6GCBozaa',
#                        'id': '1vPEPhmGDnp8RR6GCBozaa',
#                        'is_local': False,
#                        'name': 'A Lannister Always Pays His Debts',
#                        'popularity': 60,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/43d967066f07ecdf7daded0bdc521adc73a0f07a?cid=d5bf1444f570412d877d41521593ff71',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:1vPEPhmGDnp8RR6GCBozaa'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#                                               'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#                                               'id': '1hCkSJcXREhrodeIHQdav8',
#                                               'name': 'Ramin Djawadi',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#                                               'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#                                               'id': '6i9KFEJuHq78nMsQxeB1vR',
#                                               'name': 'NDR Radiophilharmonie',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BuKIq2YqVZhxSdquEnwko'},
#                                               'href': 'https://api.spotify.com/v1/artists/7BuKIq2YqVZhxSdquEnwko',
#                                               'id': '7BuKIq2YqVZhxSdquEnwko',
#                                               'name': 'Ben Palmer',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7BuKIq2YqVZhxSdquEnwko'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2Sln4IGWh4meWU5fg9tJ7G'},
#                                  'href': 'https://api.spotify.com/v1/albums/2Sln4IGWh4meWU5fg9tJ7G',
#                                  'id': '2Sln4IGWh4meWU5fg9tJ7G',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27300b1d540b9170873eecb69da',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0200b1d540b9170873eecb69da',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485100b1d540b9170873eecb69da',
#                                              'width': 64}],
#                                  'name': 'A Lannister Always Pays His Debts',
#                                  'release_date': '2020-01-31',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2Sln4IGWh4meWU5fg9tJ7G'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#                                     'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#                                     'id': '1hCkSJcXREhrodeIHQdav8',
#                                     'name': 'Ramin Djawadi',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#                                     'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#                                     'id': '6i9KFEJuHq78nMsQxeB1vR',
#                                     'name': 'NDR Radiophilharmonie',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BuKIq2YqVZhxSdquEnwko'},
#                                     'href': 'https://api.spotify.com/v1/artists/7BuKIq2YqVZhxSdquEnwko',
#                                     'id': '7BuKIq2YqVZhxSdquEnwko',
#                                     'name': 'Ben Palmer',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7BuKIq2YqVZhxSdquEnwko'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 173667,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DEE861903694'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/7bepfooXfeEsSK75XGo3W1'},
#                        'href': 'https://api.spotify.com/v1/tracks/7bepfooXfeEsSK75XGo3W1',
#                        'id': '7bepfooXfeEsSK75XGo3W1',
#                        'is_local': False,
#                        'name': 'A Lannister Always Pays His Debts',
#                        'popularity': 27,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/a93c54ddcbb0cdca02412cbd641cd6930d6a75e6?cid=d5bf1444f570412d877d41521593ff71',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:7bepfooXfeEsSK75XGo3W1'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oQJQUIpJFFnfKvHJA0xBu'},
#                                               'href': 'https://api.spotify.com/v1/artists/2oQJQUIpJFFnfKvHJA0xBu',
#                                               'id': '2oQJQUIpJFFnfKvHJA0xBu',
#                                               'name': 'The City of Prague '
#                                                       'Philharmonic Orchestra',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2oQJQUIpJFFnfKvHJA0xBu'}],
#                                  'available_markets': ['CA', 'MX', 'US'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/0kEE01IyLN3r6qGbQ1fEcx'},
#                                  'href': 'https://api.spotify.com/v1/albums/0kEE01IyLN3r6qGbQ1fEcx',
#                                  'id': '0kEE01IyLN3r6qGbQ1fEcx',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273468d0efe7ac848809770a90c',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02468d0efe7ac848809770a90c',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851468d0efe7ac848809770a90c',
#                                              'width': 64}],
#                                  'name': 'Music of Game of Thrones',
#                                  'release_date': '2017-02-24',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 21,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:0kEE01IyLN3r6qGbQ1fEcx'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oQJQUIpJFFnfKvHJA0xBu'},
#                                     'href': 'https://api.spotify.com/v1/artists/2oQJQUIpJFFnfKvHJA0xBu',
#                                     'id': '2oQJQUIpJFFnfKvHJA0xBu',
#                                     'name': 'The City of Prague Philharmonic '
#                                             'Orchestra',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:2oQJQUIpJFFnfKvHJA0xBu'}],
#                        'available_markets': ['CA', 'MX', 'US'],
#                        'disc_number': 1,
#                        'duration_ms': 164493,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBAJC1700092'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4VbVDcEsFp9lvmQXoLoui3'},
#                        'href': 'https://api.spotify.com/v1/tracks/4VbVDcEsFp9lvmQXoLoui3',
#                        'id': '4VbVDcEsFp9lvmQXoLoui3',
#                        'is_local': False,
#                        'name': 'A Lannister Always Pays His Debts',
#                        'popularity': 13,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/d6d894e7551314c235665b58c15ab684485d4681?cid=d5bf1444f570412d877d41521593ff71',
#                        'track_number': 7,
#                        'type': 'track',
#                        'uri': 'spotify:track:4VbVDcEsFp9lvmQXoLoui3'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MTfVjZzx72caVcbCjUK73'},
#                                               'href': 'https://api.spotify.com/v1/artists/4MTfVjZzx72caVcbCjUK73',
#                                               'id': '4MTfVjZzx72caVcbCjUK73',
#                                               'name': 'Dominik Hauser',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4MTfVjZzx72caVcbCjUK73'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2IGA84u1WPvJFVFUk8hadj'},
#                                  'href': 'https://api.spotify.com/v1/albums/2IGA84u1WPvJFVFUk8hadj',
#                                  'id': '2IGA84u1WPvJFVFUk8hadj',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2730fbf084b27055f9fb2132ea4',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e020fbf084b27055f9fb2132ea4',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048510fbf084b27055f9fb2132ea4',
#                                              'width': 64}],
#                                  'name': 'Game Of Thrones: Music From The '
#                                          'Television Series',
#                                  'release_date': '2015-04-07',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 17,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2IGA84u1WPvJFVFUk8hadj'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MTfVjZzx72caVcbCjUK73'},
#                                     'href': 'https://api.spotify.com/v1/artists/4MTfVjZzx72caVcbCjUK73',
#                                     'id': '4MTfVjZzx72caVcbCjUK73',
#                                     'name': 'Dominik Hauser',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4MTfVjZzx72caVcbCjUK73'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 202426,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USY251508194'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6FAHZt535KpBIBa0YMEoZW'},
#                        'href': 'https://api.spotify.com/v1/tracks/6FAHZt535KpBIBa0YMEoZW',
#                        'id': '6FAHZt535KpBIBa0YMEoZW',
#                        'is_local': False,
#                        'name': 'A Lannister Always Pays His Debts',
#                        'popularity': 15,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/d0feb71e96b94ff27d71cb2df6e6aaa49dc216cd?cid=d5bf1444f570412d877d41521593ff71',
#                        'track_number': 10,
#                        'type': 'track',
#                        'uri': 'spotify:track:6FAHZt535KpBIBa0YMEoZW'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#                                               'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#                                               'id': '6i9KFEJuHq78nMsQxeB1vR',
#                                               'name': 'NDR Radiophilharmonie',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BuKIq2YqVZhxSdquEnwko'},
#                                               'href': 'https://api.spotify.com/v1/artists/7BuKIq2YqVZhxSdquEnwko',
#                                               'id': '7BuKIq2YqVZhxSdquEnwko',
#                                               'name': 'Ben Palmer',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7BuKIq2YqVZhxSdquEnwko'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hi3goRhw04R2VLGjvNrd6'},
#                                               'href': 'https://api.spotify.com/v1/artists/0hi3goRhw04R2VLGjvNrd6',
#                                               'id': '0hi3goRhw04R2VLGjvNrd6',
#                                               'name': 'Michael England',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0hi3goRhw04R2VLGjvNrd6'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
# ...
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 161979,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'QZ22B2074602'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/2RI0QtI8qArV8fFPkTCIuN'},
#                        'href': 'https://api.spotify.com/v1/tracks/2RI0QtI8qArV8fFPkTCIuN',
#                        'id': '2RI0QtI8qArV8fFPkTCIuN',
#                        'is_local': False,
#                        'name': 'A Lannister Always Pays His Debts (From "Game '
#                                'of Thrones") [For Flute & Piano Duet]',
#                        'popularity': 0,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/4464155460a798aa1b278dbe7d463736e57d7cc3?cid=d5bf1444f570412d877d41521593ff71',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:2RI0QtI8qArV8fFPkTCIuN'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mT4rQiMcGq6OCOhjK4CYc'},
#                                               'href': 'https://api.spotify.com/v1/artists/0mT4rQiMcGq6OCOhjK4CYc',
#                                               'id': '0mT4rQiMcGq6OCOhjK4CYc',
#                                               'name': 'Philharmonic Wind '
#                                                       'Orchestra',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0mT4rQiMcGq6OCOhjK4CYc'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/70fOSWnrIv5pImxpKDtPx6'},
#                                               'href': 'https://api.spotify.com/v1/artists/70fOSWnrIv5pImxpKDtPx6',
#                                               'id': '70fOSWnrIv5pImxpKDtPx6',
#                                               'name': 'Marc Reift Orchestra',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:70fOSWnrIv5pImxpKDtPx6'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4Z6T9u4KPdqth9kNrbTPxI'},
#                                  'href': 'https://api.spotify.com/v1/albums/4Z6T9u4KPdqth9kNrbTPxI',
#                                  'id': '4Z6T9u4KPdqth9kNrbTPxI',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2736bcd3130717a24b0b9e6e6d7',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e026bcd3130717a24b0b9e6e6d7',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048516bcd3130717a24b0b9e6e6d7',
#                                              'width': 64}],
#                                  'name': 'Cinemagic 50',
#                                  'release_date': '2016-04-26',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 9,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4Z6T9u4KPdqth9kNrbTPxI'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mT4rQiMcGq6OCOhjK4CYc'},
#                                     'href': 'https://api.spotify.com/v1/artists/0mT4rQiMcGq6OCOhjK4CYc',
#                                     'id': '0mT4rQiMcGq6OCOhjK4CYc',
#                                     'name': 'Philharmonic Wind Orchestra',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:0mT4rQiMcGq6OCOhjK4CYc'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/70fOSWnrIv5pImxpKDtPx6'},
#                                     'href': 'https://api.spotify.com/v1/artists/70fOSWnrIv5pImxpKDtPx6',
#                                     'id': '70fOSWnrIv5pImxpKDtPx6',
#                                     'name': 'Marc Reift Orchestra',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:70fOSWnrIv5pImxpKDtPx6'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 378917,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'CH1601608942'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/44fC2dp8Z5BkTq3aickCuy'},
#                        'href': 'https://api.spotify.com/v1/tracks/44fC2dp8Z5BkTq3aickCuy',
#                        'id': '44fC2dp8Z5BkTq3aickCuy',
#                        'is_local': False,
#                        'name': "Main Title / The King's Arrival / Stand and "
#                                'Fight / A Lannister Always Pays His Debts / '
#                                'Finale (From "Game of Thrones")',
#                        'popularity': 1,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/3a8d3168cbb03c53b4aebd52607468a2706aaa0f?cid=d5bf1444f570412d877d41521593ff71',
#                        'track_number': 9,
#                        'type': 'track',
#                        'uri': 'spotify:track:44fC2dp8Z5BkTq3aickCuy'}],
#             'limit': 20,
#             'next': 'https://api.spotify.com/v1/search?query=A+lannister+always+pays+his+debts&type=track&offset=20&limit=20',
#             'offset': 0,
#             'previous': None,
#             'total': 60}}
